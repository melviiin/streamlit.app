# %%
import streamlit as st
import pandas as pd
import pickle

# Load the saved model
with open('hotel_booking_model.pkl', 'rb') as f:
    model = pickle.load(f)

st.title("Hotel Booking Cancellation Prediction")

st.sidebar.header("Input Booking Information")

def user_input():
    data = {
        "lead_time": st.sidebar.number_input("Lead Time", 0, 500, 100),
        "avg_price_per_room": st.sidebar.number_input("Avg Price Per Room", 0.0, 10000.0, 100.0),
        "total_nights": st.sidebar.slider("Total Nights", 1, 30, 2),
        "total_guests": st.sidebar.slider("Total Guests", 1, 10, 2),
        "no_of_previous_cancellations": st.sidebar.number_input("Previous Cancellations", 0, 10, 0),
        "no_of_previous_bookings_not_canceled": st.sidebar.number_input("Prev Bookings Not Canceled", 0, 10, 0),
        "no_of_special_requests": st.sidebar.slider("Special Requests", 0, 5, 0),
        "type_of_meal_plan": st.sidebar.selectbox("Meal Plan", ['Meal Plan 1', 'Meal Plan 2', 'Meal Plan 3', 'Not Selected']),
        "room_type_reserved": st.sidebar.selectbox("Room Type", ['Room_Type 1', 'Room_Type 2', 'Room_Type 3']),
        "market_segment_type": st.sidebar.selectbox("Market Segment", ['Online', 'Offline', 'Corporate']),
        "season": st.sidebar.selectbox("Season", ['Spring', 'Summer', 'Fall', 'Winter']),
        "arrival_month": st.sidebar.slider("Arrival Month", 1, 12, 6)
    }
    return pd.DataFrame([data])

input_df = user_input()

if st.button("Predict"):
    prediction = model.predict(input_df)[0]
    probability = model.predict_proba(input_df)[0][1]
    st.write(f"### Booking Status Prediction: {'Canceled' if prediction == 1 else 'Not Canceled'}")
    st.write(f"### Probability of Cancellation: {probability:.2%}")

# Test Case 1
if st.button("Test Case 1"):
    test_case_1 = {
        "lead_time": 50, "avg_price_per_room": 120.0, "total_nights": 3, "total_guests": 2,
        "no_of_previous_cancellations": 0, "no_of_previous_bookings_not_canceled": 1, "no_of_special_requests": 1,
        "type_of_meal_plan": "Meal Plan 1", "room_type_reserved": "Room_Type 1",
        "market_segment_type": "Online", "season": "Summer", "arrival_month": 7
    }
    df_test = pd.DataFrame([test_case_1])
    result = model.predict(df_test)[0]
    st.success(f"Test Case 1 Prediction: {'Canceled' if result == 1 else 'Not Canceled'}")

# Test Case 2
if st.button("Test Case 2"):
    test_case_2 = {
        "lead_time": 200, "avg_price_per_room": 300.0, "total_nights": 5, "total_guests": 4,
        "no_of_previous_cancellations": 2, "no_of_previous_bookings_not_canceled": 0, "no_of_special_requests": 3,
        "type_of_meal_plan": "Meal Plan 2", "room_type_reserved": "Room_Type 2",
        "market_segment_type": "Corporate", "season": "Winter", "arrival_month": 12
    }
    df_test = pd.DataFrame([test_case_2])
    result = model.predict(df_test)[0]
    st.success(f"Test Case 2 Prediction: {'Canceled' if result == 1 else 'Not Canceled'}")
# Out:
# 2025-04-22 13:50:22.178 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.568
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Lenovo\.conda\envs\mlops\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-04-22 13:50:22.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.573 Session state does not function when running a script without `streamlit run`
# 2025-04-22 13:50:22.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.600 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.607 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.613 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.613 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.623 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-22 13:50:22.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
